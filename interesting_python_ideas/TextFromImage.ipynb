# %%
from PIL import Image
imagePath = "htmlCode.png"
Image.open(imagePath)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1728x748>

# %%
from PIL import Image
from pytesseract import pytesseract

path_to_tesseract = r"C:\\Users\\jakub\\My project\\Mini_projects\\pytesseract\\Tesseract-OCR\\tesseract.exe"
path_to_iamge = imagePath
pytesseract.tesseract_cmd = path_to_tesseract
img = Image.open(path_to_iamge)
text = pytesseract.image_to_string(img)
print(text)
# Out:
# < !DOCTYPE htm1>
# <htm1 1ang="en">
# <head>
# <meta charset="UTF-8" />
# <sty1e>
# body { font-family: sans-serif; margin: lrem; }
# #prompt { width: 100%; box-sizing: border-box; }
# #response { border: 1px solid #ccc; margin-top: 1rem; padding: 0.5rem; min-heig
# </sty1e>
# </head>
# <body>
# <h2>Deep VS Code Extension</h2>
# <textarea id=“prompt" rows="3“ p1aceho1der="Ask something..."></textarea><br />
# <button id="askBtn">Ask</button>
#
# (div *id="r~p<nnn<p">(/d'i\/3 -
